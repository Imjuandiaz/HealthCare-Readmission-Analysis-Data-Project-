# %% [markdown]
# ##**PCCI ANOMALY DETECTION WITH PYOD**
#
# #IMPORTING PYOD AND DATA SET

# %%
#code snippet 1
#Installing pyod package for anormaly detection algorithms (knn)
# !pip install pyod
# Out:
# Requirement already satisfied: pyod in /usr/local/lib/python3.12/dist-packages (2.0.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from pyod) (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pyod) (3.10.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.12/dist-packages (from pyod) (2.0.2)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.12/dist-packages (from pyod) (0.60.0)
# Requirement already satisfied: scipy>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from pyod) (1.16.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from pyod) (1.6.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51->pyod) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->pyod) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyod) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pyod) (1.17.0)

# %%
#code snippet 2
#Importing pyod
from pyod.models.knn import KNN

# %%
# Code snippet 3
# Importing the dataset
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/PCCI%20Cases%20Readmit30%20Data.csv')


data
# Out:
#       Admit_Week Admit_Month Gender Marital_Status Insurance_Provider  \
# 0         Sunday         Jan      F        Married           Medicare
# 1         Sunday         Jan      M        Married           Medicare
# 2         Sunday         Jan      F         Single           Medicare
# 3         Sunday         Jan      M        Married           Medicare
# 4         Sunday         Jan      F         Single         Commercial
# ...          ...         ...    ...            ...                ...
# 12975   Saturday         Dec      M        Married           Medicare
# 12976   Saturday         Dec      F         Single           Medicaid
# 12977   Saturday         Dec      M         Single           Medicare
# 12978   Saturday         Dec      M        Married           Medicare
# 12979   Saturday         Dec      F         Single           Medicare
#
#       Tobacco_User Depression  ICU Drug_Abuse Mood_Disorder  ... Temperature  \
# 0            Never         No   No         No           Yes  ...        98.0
# 1             Quit         No   No         No            No  ...        98.0
# 2            Never         No   No         No            No  ...        98.0
# 3             Quit         No   No         No            No  ...        99.0
# 4            Never         No   No         No            No  ...        98.0
# ...            ...        ...  ...        ...           ...  ...         ...
# 12975         Quit         No  Yes         No            No  ...        97.0
# 12976         Quit         No   No         No            No  ...        99.0
# 12977         Quit         No   No         No            No  ...        97.0
# 12978         Quit         No   No         No            No  ...        99.0
# 12979          Yes         No   No         No            No  ...        98.0
#
#       Pat_Pain_Score ER_Visits IP_Visits  Chronic_Conditions  Glucose  \
# 0                  0         5         0                   8      113
# 1                  2         0         0                   7      109
# 2                  0         0         0                   6       98
# 3                  0         3         0                   7      135
# 4                  0         0         0                   2      126
# ...              ...       ...       ...                 ...      ...
# 12975              3         2         0                   4       96
# 12976              4         3         0                   7      157
# 12977              0         1         0                   5      203
# 12978              2         3         0                   5      138
# 12979              5         1         0                   7      106
#
#            Condition  Care_Plan_Following_Discharge  Cost_Of_Initial_Stay  \
# 0          Pneumonia       Skilled Nursing Facility               8004.80
# 1          Pneumonia                     Telehealth               3205.12
# 2      Heart_Failure       Skilled Nursing Facility              15694.26
# 3      Heart_Failure                     Telehealth              10014.29
# 4      Heart_Failure                     Telehealth               8798.15
# ...              ...                            ...                   ...
# 12975  Heart_Failure             Discharged to Home               5359.67
# 12976      Pneumonia             Discharged to Home               5536.30
# 12977      Pneumonia             Discharged to Home               5427.93
# 12978      Pneumonia                        Hospice               3112.01
# 12979      Pneumonia                    Home Health               6903.67
#
#        Readmit30
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 12975          0
# 12976          0
# 12977          0
# 12978          0
# 12979          0
#
# [12980 rows x 29 columns]

# %%
# Code snippet 4
# Create new dataset with only numerical columns
numeric_dataset = data.select_dtypes(include=['float64', 'int64'])
numeric_dataset
# Out:
#         Age    Bmi  Weight  Height  Pulse  Temperature  Pat_Pain_Score  \
# 0      76.6  45.89   243.0    61.0     75         98.0               0
# 1      81.6  29.44   182.0    66.0    100         98.0               2
# 2      87.9  20.51   102.0    59.0     76         98.0               0
# 3      74.3  26.93   172.0    67.0     62         99.0               0
# 4      37.3  33.72   235.0    70.0     83         98.0               0
# ...     ...    ...     ...     ...    ...          ...             ...
# 12975  65.0  31.08   192.0    66.0     75         97.0               3
# 12976  59.4  54.47   313.0    62.0    105         99.0               4
# 12977  78.2  20.96   155.0    72.0     82         97.0               0
# 12978  84.8  29.09   181.0    66.0     88         99.0               2
# 12979  72.0  21.49   121.0    63.0     64         98.0               5
#
#        ER_Visits  IP_Visits  Chronic_Conditions  Glucose  \
# 0              5          0                   8      113
# 1              0          0                   7      109
# 2              0          0                   6       98
# 3              3          0                   7      135
# 4              0          0                   2      126
# ...          ...        ...                 ...      ...
# 12975          2          0                   4       96
# 12976          3          0                   7      157
# 12977          1          0                   5      203
# 12978          3          0                   5      138
# 12979          1          0                   7      106
#
#        Cost_Of_Initial_Stay  Readmit30
# 0                   8004.80          1
# 1                   3205.12          0
# 2                  15694.26          0
# 3                  10014.29          0
# 4                   8798.15          0
# ...                     ...        ...
# 12975               5359.67          0
# 12976               5536.30          0
# 12977               5427.93          0
# 12978               3112.01          0
# 12979               6903.67          0
#
# [12980 rows x 13 columns]

# %%
# Code snippet 5
# Training with the KNN algorithm to identify the anomalies
ad_model = KNN()

# Handle missing values by imputing with the mean
numeric_dataset_cleaned = numeric_dataset.fillna(numeric_dataset.mean())

ad_model.fit(numeric_dataset_cleaned)
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
# Code snippet 6
#Predict anomalies (1 = normal, -1 = Anomaly)
anomaly_labels = ad_model.labels_
anomaly_scores = ad_model.decision_scores_

# %% [markdown]
# #ADDING LABEL TO ANOMALY LABEL AND SCORE

# %%
# Code snippet 7
# Adding the anomaly results to the original dataframe
data['Anomaly_Label'] = anomaly_labels
data['Anomaly_Score'] = anomaly_scores
data
# Out:
#       Admit_Week Admit_Month Gender Marital_Status Insurance_Provider  \
# 0         Sunday         Jan      F        Married           Medicare
# 1         Sunday         Jan      M        Married           Medicare
# 2         Sunday         Jan      F         Single           Medicare
# 3         Sunday         Jan      M        Married           Medicare
# 4         Sunday         Jan      F         Single         Commercial
# ...          ...         ...    ...            ...                ...
# 12975   Saturday         Dec      M        Married           Medicare
# 12976   Saturday         Dec      F         Single           Medicaid
# 12977   Saturday         Dec      M         Single           Medicare
# 12978   Saturday         Dec      M        Married           Medicare
# 12979   Saturday         Dec      F         Single           Medicare
#
#       Tobacco_User Depression  ICU Drug_Abuse Mood_Disorder  ... ER_Visits  \
# 0            Never         No   No         No           Yes  ...         5
# 1             Quit         No   No         No            No  ...         0
# 2            Never         No   No         No            No  ...         0
# 3             Quit         No   No         No            No  ...         3
# 4            Never         No   No         No            No  ...         0
# ...            ...        ...  ...        ...           ...  ...       ...
# 12975         Quit         No  Yes         No            No  ...         2
# 12976         Quit         No   No         No            No  ...         3
# 12977         Quit         No   No         No            No  ...         1
# 12978         Quit         No   No         No            No  ...         3
# 12979          Yes         No   No         No            No  ...         1
#
#       IP_Visits Chronic_Conditions Glucose      Condition  \
# 0             0                  8     113      Pneumonia
# 1             0                  7     109      Pneumonia
# 2             0                  6      98  Heart_Failure
# 3             0                  7     135  Heart_Failure
# 4             0                  2     126  Heart_Failure
# ...         ...                ...     ...            ...
# 12975         0                  4      96  Heart_Failure
# 12976         0                  7     157      Pneumonia
# 12977         0                  5     203      Pneumonia
# 12978         0                  5     138      Pneumonia
# 12979         0                  7     106      Pneumonia
#
#        Care_Plan_Following_Discharge  Cost_Of_Initial_Stay  Readmit30  \
# 0           Skilled Nursing Facility               8004.80          1
# 1                         Telehealth               3205.12          0
# 2           Skilled Nursing Facility              15694.26          0
# 3                         Telehealth              10014.29          0
# 4                         Telehealth               8798.15          0
# ...                              ...                   ...        ...
# 12975             Discharged to Home               5359.67          0
# 12976             Discharged to Home               5536.30          0
# 12977             Discharged to Home               5427.93          0
# 12978                        Hospice               3112.01          0
# 12979                    Home Health               6903.67          0
#
#        Anomaly_Label  Anomaly_Score
# 0                  0      44.010929
# 1                  0      33.836969
# 2                  0      63.906416
# 3                  0      54.278771
# 4                  0      49.707980
# ...              ...            ...
# 12975              0      26.500811
# 12976              0      60.404246
# 12977              0      46.006769
# 12978              0      31.830394
# 12979              0      39.960622
#
# [12980 rows x 31 columns]

# %% [markdown]
# #IMPORTING DATA SET WITH ANOMALY COLUMNS

# %%
# Code snippet 8
# Exporting the dataset to a csv file with anomaly info
data.to_csv('PCCI_KNN_Anomalies.csv', index=False)

# %% [markdown]
# #TOTAL COUNT OF ANOMALY ON DATASET

# %%
# Code snippet 9
# Displaying the number of anomalies
num_anomalies = (data['Anomaly_Label'] == 1).sum()
print(f"Number of anomalies: {num_anomalies}")
# Out:
# Number of anomalies: 1298
