# %%
#code snippet 1
#Installing h2o
# !pip install h2o
# Out:
# Collecting h2o
#   Downloading h2o-3.46.0.7-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from h2o) (2.32.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from h2o) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (2025.8.3)
# Downloading h2o-3.46.0.7-py2.py3-none-any.whl (265.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 MB 4.7 MB/s eta 0:00:00
# Installing collected packages: h2o
# Successfully installed h2o-3.46.0.7

# %%
#code snippet 2
#Importing h2o
import h2o

#initialize h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.28" 2025-07-15; OpenJDK Runtime Environment (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1); OpenJDK 64-Bit Server VM (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.12/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp6cbjro99
#   JVM stdout: /tmp/tmp6cbjro99/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmp6cbjro99/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# Warning: Your H2O cluster version is (6 months and 11 days) old.  There may be a newer version available.
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.7
# H2O_cluster_version_age:    6 months and 11 days
# H2O_cluster_name:           H2O_from_python_unknownUser_k5yb4n
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.168 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.12.11 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
# Code snippet 3
# Importing dataset
data = h2o.import_file('https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/PCCI%20Cases%20Readmit30%20Data.csv')


data
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Admit_Week    Admit_Month    Gender    Marital_Status    Insurance_Provider    Tobacco_User    Depression    ICU    Drug_Abuse    Mood_Disorder    Diabetes    Anxiety    Obesity    Dementia      Age      Bmi    Weight    Height    Pulse    Temperature    Pat_Pain_Score    ER_Visits    IP_Visits    Chronic_Conditions    Glucose  Condition      Care_Plan_Following_Discharge      Cost_Of_Initial_Stay    Readmit30
# ------------  -------------  --------  ----------------  --------------------  --------------  ------------  -----  ------------  ---------------  ----------  ---------  ---------  ----------  -----  -------  --------  --------  -------  -------------  ----------------  -----------  -----------  --------------------  ---------  -------------  -------------------------------  ----------------------  -----------
# Sunday        Jan            F         Married           Medicare              Never           No            No     No            Yes              No          No         No         Yes          76.6  45.89         243        61       75             98                 0            5            0                     8        113  Pneumonia      Skilled Nursing Facility                        8004.8             1
# Sunday        Jan            M         Married           Medicare              Quit            No            No     No            No               No          No         No         No           81.6  29.44         182        66      100             98                 2            0            0                     7        109  Pneumonia      Telehealth                                      3205.12            0
# Sunday        Jan            F         Single            Medicare              Never           No            No     No            No               No          No         No         No           87.9  20.51         102        59       76             98                 0            0            0                     6         98  Heart_Failure  Skilled Nursing Facility                       15694.3             0
# Sunday        Jan            M         Married           Medicare              Quit            No            No     No            No               No          No         No         No           74.3  26.93         172        67       62             99                 0            3            0                     7        135  Heart_Failure  Telehealth                                     10014.3             0
# Sunday        Jan            F         Single            Commercial            Never           No            No     No            No               No          No         No         No           37.3  33.72         235        70       83             98                 0            0            0                     2        126  Heart_Failure  Telehealth                                      8798.15            0
# Sunday        Jan            F         Single            Medicare              Never           No            No     No            No               No          No         No         No           85.2  30.55         162        61       86             98                 2            0            0                     7        127  Pneumonia      Telehealth                                      6068.43            0
# Sunday        Jan            F         Single            Medicare              Quit            No            No     No            No               No          No         No         No           85.6  32.03         181       nan       86             98                 5            0            0                     5         99  Pneumonia      Home Health                                     4695.7             0
# Sunday        Jan            F         Single            Medicaid              Quit            No            No     No            No               No          Yes        Yes        No           28.1  43.1281       260        65       68             98                 6            2            0                     7        134  Pneumonia      Home Health                                     1704.47            0
# Sunday        Jan            M         Single            Commercial            Yes             No            No     No            No               No          No         No         No           44.5  28.73         212        72       62             98                 1            2            0                     4         94  Pneumonia      Telehealth                                      2853.38            0
# Sunday        Jan            F         Single            Medicare              Never           No            No     No            No               No          No         No         No           72.4  22.23         134        65       72             98                 2            1            0                     4        132  Pneumonia      Telehealth                                      3028.25            0
# [12980 rows x 29 columns]

# %%
#code snippet 4
#Importing Kmeans Estimator
from h2o.estimators.kmeans import H2OKMeansEstimator

# %%
#code snippet 5
#setting the number of clusters in the data train as 4
kmeans_model = H2OKMeansEstimator(k=4)

#Train the clustering model
kmeans_model.train(training_frame=data)
# Out:
# kmeans Model Build progress: |███████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OKMeansEstimator : K-means
# Model Key: KMeans_model_python_1759944094771_2
#
#
# Model Summary:
#     number_of_rows    number_of_clusters    number_of_categorical_columns    number_of_iterations    within_cluster_sum_of_squares    total_sum_of_squares    between_cluster_sum_of_squares
# --  ----------------  --------------------  -------------------------------  ----------------------  -------------------------------  ----------------------  --------------------------------
#     12980             4                     16                               10                      192475                           231359                  38883.8
#
# ModelMetricsClustering: kmeans
# ** Reported on train data. **
#
# Total Within Cluster Sum of Square Error: 192227.42734439787
# Total Sum of Square Error to Grand Mean: 231359.0000235799
# Between Cluster Sum of Square Error: 39131.57267918202
#
# Centroid Statistics:
#     centroid    size    within_cluster_sum_of_squares
# --  ----------  ------  -------------------------------
#     1           4235    53434.8
#     2           1829    42983
#     3           2726    43009
#     4           4190    52800.7
#
# Scoring History:
#     timestamp            duration    iterations    number_of_reassigned_observations    within_cluster_sum_of_squares
# --  -------------------  ----------  ------------  -----------------------------------  -------------------------------
#     2025-10-08 17:25:01  0.005 sec   0             nan                                  nan
#     2025-10-08 17:25:01  0.212 sec   1             12980                                292954
#     2025-10-08 17:25:01  0.248 sec   2             2816                                 204413
#     2025-10-08 17:25:01  0.280 sec   3             1423                                 201253
#     2025-10-08 17:25:01  0.303 sec   4             1034                                 199696
#     2025-10-08 17:25:01  0.335 sec   5             1066                                 197951
#     2025-10-08 17:25:01  0.370 sec   6             1223                                 195868
#     2025-10-08 17:25:01  0.400 sec   7             852                                  194504
#     2025-10-08 17:25:01  0.431 sec   8             1138                                 193356
#     2025-10-08 17:25:01  0.469 sec   9             502                                  192948
#     2025-10-08 17:25:01  0.494 sec   10            664                                  192475
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
#code snippet 6
#Displaying the cluster size
kmeans_model.size()
# Out:
# [4235.0, 1829.0, 2726.0, 4190.0]

# %%
# Code Snippet 7
# Import libraries
import pandas as pd

# Predict clusters for each row
pred = kmeans_model.predict(data)

# Join prediction to the original dataset
data_with_clusters = data.cbind(pred)

# Convert to pandas DataFrame
df = data_with_clusters.as_data_frame()

# ==========================
# Numeric variables
# ==========================
numeric_cols = [
    "Age", "Bmi", "Weight", "Height", "Pulse", "Temperature",
    "Pat_Pain_Score", "ER_Visits", "IP_Visits", "Chronic_Conditions",
    "Glucose", "Cost_Of_Initial_Stay"
]

numeric_summary = df.groupby("predict")[numeric_cols].mean()

# ==========================
# Categorical variables
# ==========================
categorical_cols = [
    "Admit_Week", "Admit_Month", "Gender", "Marital_Status",
    "Insurance_Provider", "Tobacco_User", "Depression", "ICU",
    "Drug_Abuse", "Mood_Disorder", "Diabetes", "Anxiety",
    "Obesity", "Dementia", "Condition", "Care_Plan_Following_Discharge"
]

categorical_summary = {}
for col in categorical_cols:
    categorical_summary[col] = (
        df.groupby("predict")[col]
        .value_counts(normalize=True)
        .unstack(fill_value=0)
    )
# Out:
# kmeans prediction progress: |████████████████████████████████████████████████████| (done) 100%
# /usr/local/lib/python3.12/dist-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
# ==========================
# Code Snippet 8
# ==========================
# Combine summaries
# ==========================

# Merge all categorical summary DataFrames into a single one
categorical_df = pd.concat(categorical_summary.values(), axis=1)

# Combine with numeric summary
cluster_profiles = numeric_summary.join(categorical_df, how="left")

# Export to CSV
cluster_profiles.to_csv("cluster_profiles.csv", index=True)

# Display in console
print(cluster_profiles)
# Out:
#                Age        Bmi      Weight     Height      Pulse  Temperature  \
# predict
# 0        71.486612  25.824533  174.629314  68.941462  81.607320    97.770815
# 1        68.694697  31.358522  197.472329  66.589556  78.971022    97.754446
# 2        62.439582  41.325564  270.393605  67.771837  77.422964    97.638454
# 3        78.996086  27.304425  153.049259  62.788387  76.397613    97.695587
#
#          Pat_Pain_Score  ER_Visits  IP_Visits  Chronic_Conditions  ...  \
# predict                                                            ...
# 0              1.458796   0.990791   0.064699            4.780165  ...
# 1              3.468015   4.669765   0.522143           10.480044  ...
# 2              2.087674   1.268892   0.050257            6.799707  ...
# 3              1.694033   1.398091   0.062530            6.654177  ...
#
#                No       Yes  Heart_Failure  Pneumonia  Discharged to Home  \
# predict
# 0        0.948760  0.051240       0.342385   0.657615            0.393388
# 1        0.904319  0.095681       0.647895   0.352105            0.207217
# 2        0.942040  0.057960       0.578870   0.421130            0.400954
# 3        0.923389  0.076611       0.611217   0.388783            0.204296
#
#           Expired  Home Health   Hospice  Skilled Nursing Facility  Telehealth
# predict
# 0        0.041795     0.171192  0.044392                  0.182527    0.166706
# 1        0.033352     0.346638  0.050847                  0.238382    0.123565
# 2        0.019076     0.230741  0.013940                  0.146368    0.188921
# 3        0.033413     0.315990  0.045107                  0.269212    0.131981
#
# [4 rows x 67 columns]
